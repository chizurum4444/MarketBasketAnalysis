# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
#Hashing function
def h(values):
    return sum([int(x) + 6 for x in values]) % 100000

def create_pairs(items):
    pairs = []
    items = [int(x) for x in items]
    items = sorted (items)
    for i in range(len(items)):
        for j in range(i+1, len(items)):
            pairs.append((items[i],items[j]))
    return pairs

# %%
retail = pd.read_csv('http://fimi.uantwerpen.be/data/retail.dat')
records = retail.values.tolist()
for i in range(len(records)):
    records[i] = records[i][0].split()

# %%
percentages = [0.2,0.4,0.6,0.8,1]
thresholds = [0.01, 0.02, 0.05]
samples = []
durations = []

# Loop through percentages and make random samples 
for percentage in percentages:
    samples.append(records[0:int(len(records)*percentage)])

# %%
c = 0
# For loop to iterate trhough samples list
for s in samples:
    print(f'COMPUTING {percentages[c]*100}% OF DATASET')
    # For loop to iterate through thresholds list
    for x in thresholds:
        items = {}
        hash_table = np.zeros(100000)
        thereshold = len(s)*x
        start = time.time()
        
     # Finding frequent items in the dataset, creating pairs of items, and hashing pairs to a hashtable
        for i in range(len(s)):
            for j in range(len(s[i])):
                if s[i][j] not in items:
                    items[s[i][j]] = 0 
                items[s[i][j]] += 1
                pairs = create_pairs(s[i])
                for pair in pairs:
                    hash_table[h(pair)] += 1

        C1 = pd.DataFrame({
            'Itemset': items.keys(),
            'Support': items.values()
        })
        L1 = C1.loc[(C1['Support']) >= thereshold] #Pruning frequent items list with threshold

        # Creating a bitmap for items greater than threshold from the hashtable 
        bitmap = np.zeros(100000, dtype=bool)
        for i in range(len(bitmap)):
            bitmap[i] = hash_table[i] >= thereshold

        arr = []
        for i in L1['Itemset']:
            for j in L1['Itemset']:
                if i == j:
                    pass
                else:
                    for k in s:
                        if i in k and j in k and [i,j,0] not in arr and [j,i,0] not in arr:
                            arr.append([i,j,0])

        for i in range(len(arr)):
                    for j in records:
                        if arr[i][0] in j and arr[i][1] in j and bitmap[h((arr[i][0],arr[i][1]))]:
                            arr[i][2] += 1

        C2 = pd.DataFrame(arr, columns=['Item 1','Item 2','Count'])
        L2 = C2.loc[(C2['Count']) >= thereshold]
        end = time.time()
        duration = end-start
        durations.append(duration)
        print(f'\tFINISHED RUNNING THRESHOLD {x} \t{duration}s')
    print(f'COMPUTED {percentages[c]*100}% OF DATASET\t{durations[-1]+durations[-2]+durations[-3]}s')    
    c+=1
    print('----------------------------------------------------------------------')
print("Durations: \t",durations)
# Out:
# COMPUTING 20.0% OF DATASET
# 	FINISHED RUNNING THRESHOLD 0.01 	58.129043102264404s
# 	FINISHED RUNNING THRESHOLD 0.02 	19.514853715896606s
# 	FINISHED RUNNING THRESHOLD 0.05 	15.267215728759766s
# COMPUTED 20.0% OF DATASET	92.91111254692078s
# ----------------------------------------------------------------------
# COMPUTING 40.0% OF DATASET
# 	FINISHED RUNNING THRESHOLD 0.01 	87.97158813476562s
# 	FINISHED RUNNING THRESHOLD 0.02 	35.458913803100586s
# 	FINISHED RUNNING THRESHOLD 0.05 	31.053265810012817s
# COMPUTED 40.0% OF DATASET	154.48376774787903s
# ----------------------------------------------------------------------
# COMPUTING 60.0% OF DATASET
# 	FINISHED RUNNING THRESHOLD 0.01 	104.66226387023926s
# 	FINISHED RUNNING THRESHOLD 0.02 	50.84667420387268s
# 	FINISHED RUNNING THRESHOLD 0.05 	45.54771590232849s
# COMPUTED 60.0% OF DATASET	201.05665397644043s
# ----------------------------------------------------------------------
# COMPUTING 80.0% OF DATASET
# 	FINISHED RUNNING THRESHOLD 0.01 	125.52530217170715s
# 	FINISHED RUNNING THRESHOLD 0.02 	65.61412119865417s
# 	FINISHED RUNNING THRESHOLD 0.05 	60.01997900009155s
# COMPUTED 80.0% OF DATASET	251.15940237045288s
# ----------------------------------------------------------------------
# COMPUTING 100% OF DATASET
# 	FINISHED RUNNING THRESHOLD 0.01 	166.77116203308105s
# 	FINISHED RUNNING THRESHOLD 0.02 	83.68949890136719s
# 	FINISHED RUNNING THRESHOLD 0.05 	77.09071803092957s
# COMPUTED 100% OF DATASET	327.5513789653778s
# ----------------------------------------------------------------------
# Durations: 	 [58.129043102264404, 19.514853715896606, 15.267215728759766, 87.97158813476562, 35.458913803100586, 31.053265810012817, 104.66226387023926, 50.84667420387268, 45.54771590232849, 125.52530217170715, 65.61412119865417, 60.01997900009155, 166.77116203308105, 83.68949890136719, 77.09071803092957]

# %%
x = np.arange(20, 120, 20)
plt.title("Line graph")
plt.xlabel("Percentage of Dataset")
plt.ylabel("Time")
plt.plot(x, durations[0:13:3], color = "red", label = '0.01')
plt.plot(x, durations[1:14:3], color = "green", label = '0.02')
plt.plot(x, durations[2:15:3], color = "blue", label = '0.05')
plt.legend()
plt.show()
